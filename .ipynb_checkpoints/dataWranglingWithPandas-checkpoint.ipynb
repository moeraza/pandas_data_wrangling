# %% [markdown]
# ## Data Wrangling in Pandas
#  ![text_here](images/img_one.jpg)

# %%
import pandas as pd

# %%
filename = 'data/breast_cancer_data.csv'

# %%
df = pd.read_csv(filename)
# df = pd.read_excel(filename)

# %%
df.columns
# Out:
# Index(['patient_id', 'clump_thickness', 'cell_size_uniformity',
#        'cell_shape_uniformity', 'marginal_adhesion', 'single_ep_cell_size',
#        'bare_nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses',
#        'class'],
#       dtype='object')

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.columns = ['patient_id', 'clump_thickness', 'cell_size_uniformity',
       'cell_shape_uniformity', 'marginal_adhesion', 'single_ep_cell_size',
       'bare_nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses',
       'class']

# %%
df.to_csv(filename, index =False)

# %%
df
def f(x):
    if x ==2:
        return('benign')
    elif x ==4:
        return('malignant')

df['class'] = df['class'].transform(f)

# %%
df['doctor_name'] = 'e'

# %%
import numpy as np
for i in range(0,10,1):
    print(np.random.randint(low=0, high=4))
# Out:
# 3
# 0
# 0
# 1
# 1
# 1
# 0
# 2
# 1
# 2

# %%
df.iloc[:,11]
# Out:
# 0      e
# 1      e
# 2      e
# 3      e
# 4      e
# 5      e
# 6      e
# 7      e
# 8      e
# 9      e
# 10     e
# 11     e
# 12     e
# 13     e
# 14     e
# 15     e
# 16     e
# 17     e
# 18     e
# 19     e
# 20     e
# 21     e
# 22     e
# 23     e
# 24     e
# 25     e
# 26     e
# 27     e
# 28     e
# 29     e
#       ..
# 669    e
# 670    e
# 671    e
# 672    e
# 673    e
# 674    e
# 675    e
# 676    e
# 677    e
# 678    e
# 679    e
# 680    e
# 681    e
# 682    e
# 683    e
# 684    e
# 685    e
# 686    e
# 687    e
# 688    e
# 689    e
# 690    e
# 691    e
# 692    e
# 693    e
# 694    e
# 695    e
# 696    e
# 697    e
# 698    e
# Name: doctor_name, Length: 699, dtype: object

# %%
doctors = ['Dr. Wong','Dr. Lee','Dr. Smith','Dr. Doe']
for i in range(0, df.shape[0]):
    df.iloc[i,11] = doctors[np.random.randint(low=0, high=4)]

# %%
df.patient_id.nunique()
# Out:
# 645

# %% [markdown]
# ## Data Exploration

# %%
#start of by actually looking at your data set
df
# Out:
#      patient_id  clump_thickness  cell_size_uniformity  cell_shape_uniformity  \
# 0       1000025              5.0                   1.0                      1
# 1       1002945              5.0                   4.0                      4
# 2       1015425              3.0                   1.0                      1
# 3       1016277              6.0                   8.0                      8
# 4       1017023              4.0                   1.0                      1
# 5       1017122              8.0                  10.0                     10
# 6       1018099              1.0                   NaN                      1
# 7       1018561              2.0                   1.0                      2
# 8       1033078              2.0                   1.0                      1
# 9       1033078              4.0                   2.0                      1
# 10      1035283              1.0                   1.0                      1
# ...

# %%
df.nunique()
# Out:
# patient_id               645
# clump_thickness           10
# cell_size_uniformity      10
# cell_shape_uniformity     10
# marginal_adhesion         10
# single_ep_cell_size       10
# bare_nuclei               11
# bland_chromatin           10
# normal_nucleoli           10
# mitoses                    9
# class                      2
# doctor_name                4
# dtype: int64

# %%
df

# %%
df.shape
# Out:
# (699, 12)

# %%
df.columns
# Out:
# Index(['patient_id', 'clump_thickness', 'cell_size_uniformity',
#        'cell_shape_uniformity', 'marginal_adhesion', 'single_ep_cell_size',
#        'bare_nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'class',
#        'doctor_name'],
#       dtype='object')

# %%
df.describe()
# Out:
#          patient_id  clump_thickness  cell_size_uniformity  \
# count  6.990000e+02       698.000000            698.000000
# mean   1.071704e+06         4.416905              3.137536
# std    6.170957e+05         2.817673              3.052575
# min    6.163400e+04         1.000000              1.000000
# 25%    8.706885e+05         2.000000              1.000000
# 50%    1.171710e+06         4.000000              1.000000
# 75%    1.238298e+06         6.000000              5.000000
# max    1.345435e+07        10.000000             10.000000
#
#        cell_shape_uniformity  marginal_adhesion  single_ep_cell_size  \
# count             699.000000         699.000000           699.000000
# mean                3.207439           2.793991             3.216023
# std                 2.971913           2.843163             2.214300
# min                 1.000000           1.000000             1.000000
# 25%                 1.000000           1.000000             2.000000
# ...

# %%
#Unique values in a column
df.nunique()
# Out:
# patient_id               645
# clump_thickness           10
# cell_size_uniformity      10
# cell_shape_uniformity     10
# marginal_adhesion         10
# single_ep_cell_size       10
# bare_nuclei               11
# bland_chromatin           10
# normal_nucleoli           10
# mitoses                    9
# class                      2
# dtype: int64

# %%
test = df.groupby(by = 'patient_id').size()
repeat_patients = test[test >1]
repeat_patients = repeat_patients.to_frame()
repeat_patients = repeat_patients.reset_index()

# %%
joinOne = pd.merge(repeat_patients, df, on ='patient_id', how = 'left')

# %%
joinOne
# Out:
#     patient_id  0  clump_thickness  cell_size_uniformity  \
# 0       320675  2              3.0                   3.0
# 1       320675  2              3.0                   3.0
# 2       385103  2              1.0                   1.0
# 3       385103  2              5.0                   1.0
# 4       411453  2              5.0                   1.0
# 5       411453  2              1.0                   1.0
# 6       466906  2              1.0                   1.0
# 7       466906  2              1.0                   1.0
# 8       493452  2              1.0                   1.0
# 9       493452  2              4.0                   1.0
# 10      560680  2              1.0                   1.0
# 11      560680  2              3.0                   1.0
# 12      654546  2              1.0                   1.0
# 13      654546  2              1.0                   1.0
# 14      695091  2              1.0                   1.0
# ...

# %%
df[df.patient_id ==385103 ]
# Out:
#      patient_id  clump_thickness  cell_size_uniformity  cell_shape_uniformity  \
# 269      385103              1.0                   1.0                      1
# 575      385103              5.0                   1.0                      2
#
#      marginal_adhesion  single_ep_cell_size bare_nuclei  bland_chromatin  \
# 269                  1                    2           1              3.0
# 575                  1                    2           1              3.0
#
#      normal_nucleoli  mitoses   class doctor_name
# 269              1.0        1  benign     Dr. Doe
# 575              1.0        1  benign     Dr. Doe

# %%
#Now that I have seen that there are some duplicates, I am going to go ahead and remove any duplicate rows
#, same things that occours twice

df.drop_duplicates()

#Now lets say you arent satisified with these duplciate patients, and you want to remove them from your dataset 
#entierley, how would you do this ?

df[~df.patient_id.isin(repeat_patients.patient_id)]

# %%
df.cell_shape_uniformity >2
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13     False
# 14      True
# 15      True
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24     False
# 25      True
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 669     True
# 670     True
# 671    False
# 672    False
# 673    False
# 674    False
# 675     True
# 676    False
# 677    False
# 678    False
# 679    False
# 680     True
# 681     True
# 682    False
# 683    False
# 684    False
# 685    False
# 686    False
# 687    False
# 688    False
# 689    False
# 690    False
# 691     True
# 692    False
# 693    False
# 694    False
# 695    False
# 696     True
# 697     True
# 698     True
# Name: cell_shape_uniformity, Length: 699, dtype: bool

# %%
#Curious to see how many times these values repeat themselves?
df = df.groupby(df.cust_num, df.).size()
df = df.groupby(df.cust_num).count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-110b2ced24d1> in <module>()
# ----> 1 df.describe()
#       2 df.shape
#       3 #Unique values ina . column
#       4 df['col_name'].nunique()
#       5
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Filtering

# %%
print(1==1)
print(~1==1)
# Out:
# True
# False

# %%
#Basic filtering
df = df[(df.col_one ==1) & (df.col_two == 1)]
df = df[(df.col_one ==1) or (df.col_two == 1)]

#Reverse conditional filtering
df = df[~(df.col_one ==1) & (df.col_two == 1)]

# %%
#What if i want to see if individuals

# %%
##NEED TO REMOVE TD DOUBLE customers ---> customers who get approved dont fund, then reapply and get funded
check = tb2[(tb2.Approved_Ind ==1) & (tb2.Release_Ind==1)]
test = tb2[(tb2.Approved_Ind ==1) & (tb2.Release_Ind==0)]
awx_ppl = pd.merge(check, test, how='inner', on='cust_num') #this gives a DF of all ppl who duped
lst1 = awx_ppl['cust_num'].tolist() # THis gives a list of all the custnums who duped 
filterd_df = test[~test.cust_num.isin(lst1)] # this is a FILTERED list df of custnums who REALLY didnt fund with TD
lst2 = filterd_df.cust_num.to_frame()

td_gone_cust = pd.merge(lst2, tb1c, on ='cust_num', how='left')
td_gone_cust = td_gone_cust.fillna(0)

# %% [markdown]
# ## Data Preproccessing

# %%
#Dealing with missing values?
df.isna().sum() #How many np.nan per column?
df = df.fillna(0) #fill with zero
df = dropna()  #drop rows with any column having np.nan values

#Rename columns
df.columns = ['cust_num','reapply_num']
df.rename(columns = {'y':'year'})

# %% [markdown]
# ### One Hot Encoding Catergorical Data

# %%
categorical_df = df[['patient_id', 'doctor_name']]

# %%
categorical_df['holder'] = 1
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
categorical_df
# Out:
#      patient_id doctor_name  holder
# 0       1000025    Dr. Wong       1
# 1       1002945   Dr. Smith       1
# 2       1015425     Dr. Doe       1
# 3       1016277   Dr. Smith       1
# 4       1017023    Dr. Wong       1
# 5       1017122     Dr. Lee       1
# 6       1018099    Dr. Wong       1
# 7       1018561    Dr. Wong       1
# 8       1033078    Dr. Wong       1
# 9       1033078   Dr. Smith       1
# 10      1035283   Dr. Smith       1
# 11      1036172    Dr. Wong       1
# 12      1041801   Dr. Smith       1
# 13      1043999   Dr. Smith       1
# 14      1044572     Dr. Lee       1
# 15      1047630     Dr. Doe       1
# 16      1048672   Dr. Smith       1
# 17      1049815   Dr. Smith       1
# 18      1050670     Dr. Doe       1
# 19      1050718     Dr. Doe       1
# 20      1054590    Dr. Wong       1
# 21      1054593     Dr. Doe       1
# 22      1056784     Dr. Lee       1
# 23      1057013   Dr. Smith       1
# 24      1059552    Dr. Wong       1
# ...

# %%
one_hot_encoded  = pd.pivot_table(categorical_df
                                  ,index = categorical_df.index , 
                                  columns = ['doctor_name'], values = ['holder'])

# %%
one_hot_encoded
one_hot_encoded.columns = one_hot_encoded.columns.droplevel()

# %%
one_hot_encoded
# Out:
# doctor_name  Dr. Doe  Dr. Lee  Dr. Smith  Dr. Wong
# 0                NaN      NaN        NaN       1.0
# 1                NaN      NaN        1.0       NaN
# 2                1.0      NaN        NaN       NaN
# 3                NaN      NaN        1.0       NaN
# 4                NaN      NaN        NaN       1.0
# 5                NaN      1.0        NaN       NaN
# 6                NaN      NaN        NaN       1.0
# 7                NaN      NaN        NaN       1.0
# 8                NaN      NaN        NaN       1.0
# 9                NaN      NaN        1.0       NaN
# 10               NaN      NaN        1.0       NaN
# 11               NaN      NaN        NaN       1.0
# 12               NaN      NaN        1.0       NaN
# 13               NaN      NaN        1.0       NaN
# 14               NaN      1.0        NaN       NaN
# 15               1.0      NaN        NaN       NaN
# 16               NaN      NaN        1.0       NaN
# ...

# %%
combined_df = pd.merge(df, one_hot_encoded, left_index = True,right_index =True, how ='left')

# %%
combined_df
# Out:
#      patient_id  clump_thickness  cell_size_uniformity  cell_shape_uniformity  \
# 0       1000025              5.0                   1.0                      1
# 1       1002945              5.0                   4.0                      4
# 2       1015425              3.0                   1.0                      1
# 3       1016277              6.0                   8.0                      8
# 4       1017023              4.0                   1.0                      1
# 5       1017122              8.0                  10.0                     10
# 6       1018099              1.0                   NaN                      1
# 7       1018561              2.0                   1.0                      2
# 8       1033078              2.0                   1.0                      1
# 9       1033078              4.0                   2.0                      1
# 10      1035283              1.0                   1.0                      1
# ...

# %%
df = pd.pivot_table(df2, values = ['NoOfMTGs', 'TotalLimit'], index =['cust_num'], columns =['Date_Key'])

df.reset_index()

# %% [markdown]
# #### Joining Data

# %%
combined_df = pd.merge(df1, df2, on ='col_name', how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-199-083434dfb3b7> in <module>()
# ----> 1 combined_df = pd.merge(df1, df2, how='left')
#
# NameError: name 'df1' is not defined

# %% [markdown]
# ## Making new columns and conducting elementise operations

# %%
#Making a new column based on a nuemrical calcualtion of other columns in the df
df['new_col_name'] = df.col_1*col_2

#what if you want to crete a new column based on charecteristics of another column

def f(x):
    if x>10:
        print('big')
    elif x >5 and x<10:
        print('medium')
    else:
        print('not_classified')
    
df['new_col_name'] = df['col_name'].transform(f)

# %%
#What if we want to do something more complex and create a new column based on charecterisitcs of multiple columns

for i in range(0,df.shape[0],1):
    if (df.iloc[i,3] > df.iloc[i,2]):
        df.iloc[i,7] = -1
    elif ((df.iloc[i,3] == df.iloc[i,2])):
        df.iloc[i,7] = 0
    elif ((df.iloc[i,3] < df.iloc[i,2]):
        df.iloc[i,7] = 0
    else:
        df.iloc[i,7] = 'awx'
